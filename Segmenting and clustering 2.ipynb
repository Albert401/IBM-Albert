# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4) (1.7.1)
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Requirement already satisfied: html5lib in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: webencodings in /opt/conda/envs/Python36/lib/python3.6/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests) (3.0.4)

# %%
import pandas as pd
import numpy as np

# %%
table = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
print(table[0])
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M6A        North York
# 6        M6A        North York
# 7        M7A  Downtown Toronto
# 8        M8A      Not assigned
# 9        M9A      Queen's Park
# 10       M1B       Scarborough
# 11       M1B       Scarborough
# 12       M2B      Not assigned
# 13       M3B        North York
# 14       M4B         East York
# 15       M4B         East York
# 16       M5B  Downtown Toronto
# 17       M5B  Downtown Toronto
# 18       M6B        North York
# 19       M7B      Not assigned
# 20       M8B      Not assigned
# 21       M9B         Etobicoke
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M1C       Scarborough
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M2C      Not assigned
# ..       ...               ...
# 257      M9X      Not assigned
# 258      M1Y      Not assigned
# 259      M2Y      Not assigned
# 260      M3Y      Not assigned
# 261      M4Y  Downtown Toronto
# 262      M5Y      Not assigned
# 263      M6Y      Not assigned
# 264      M7Y      East Toronto
# 265      M8Y         Etobicoke
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M9Y      Not assigned
# 274      M1Z      Not assigned
# 275      M2Z      Not assigned
# 276      M3Z      Not assigned
# 277      M4Z      Not assigned
# 278      M5Z      Not assigned
# 279      M6Z      Not assigned
# 280      M7Z      Not assigned
# 281      M8Z         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                     Lawrence Heights
# 6                                       Lawrence Manor
# 7                                         Queen's Park
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                               Rouge
# 11                                             Malvern
# 12                                        Not assigned
# 13                                     Don Mills North
# 14                                    Woodbine Gardens
# 15                                       Parkview Hill
# 16                                             Ryerson
# 17                                     Garden District
# 18                                           Glencairn
# 19                                        Not assigned
# 20                                        Not assigned
# 21                                          Cloverdale
# 22                                           Islington
# 23                                        Martin Grove
# 24                                    Princess Gardens
# 25                                     West Deane Park
# 26                                      Highland Creek
# 27                                          Rouge Hill
# 28                                          Port Union
# 29                                        Not assigned
# ..                                                 ...
# 257                                       Not assigned
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                               Church and Wellesley
# 262                                       Not assigned
# 263                                       Not assigned
# 264  Business Reply Mail Processing Centre 969 Eastern
# 265                                         Humber Bay
# 266                                   King's Mill Park
# 267                           Kingsway Park South East
# 268                                          Mimico NE
# 269                                     Old Mill South
# 270                                 The Queensway East
# 271                              Royal York South East
# 272                                           Sunnylea
# 273                                       Not assigned
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                           Kingsway Park South West
# 282                                          Mimico NW
# 283                                 The Queensway West
# 284                              Royal York South West
# 285                                     South of Bloor
# 286                                       Not assigned
#
# [287 rows x 3 columns]

# %%
data = pd.DataFrame(table[0])
data.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
# 7      M7A  Downtown Toronto      Queen's Park
# 8      M8A      Not assigned      Not assigned
# 9      M9A      Queen's Park      Not assigned

# %%
df = data.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(list)
df = df.sample(frac=1).reset_index()
df['Neighbourhood'] = df['Neighbourhood'].str.join(', ')
df
# Out:
#     Postcode           Borough  \
# 0        M3J        North York
# 1        M3B        North York
# 2        M7P      Not assigned
# 3        M2A      Not assigned
# 4        M7C      Not assigned
# 5        M2E      Not assigned
# 6        M4J         East York
# 7        M7K      Not assigned
# 8        M7G      Not assigned
# 9        M5L  Downtown Toronto
# 10       M8B      Not assigned
# 11       M7Y      East Toronto
# 12       M6X      Not assigned
# 13       M7Z      Not assigned
# 14       M9R         Etobicoke
# 15       M8P      Not assigned
# 16       M9A      Queen's Park
# 17       M8X         Etobicoke
# 18       M8S      Not assigned
# 19       M1T       Scarborough
# 20       M7X      Not assigned
# 21       M8Z         Etobicoke
# 22       M7M      Not assigned
# 23       M4G         East York
# 24       M1M       Scarborough
# 25       M6V      Not assigned
# 26       M8A      Not assigned
# 27       M4E      East Toronto
# 28       M5M        North York
# 29       M2S      Not assigned
# ..       ...               ...
# 150      M6Y      Not assigned
# 151      M7B      Not assigned
# 152      M9Y      Not assigned
# 153      M8N      Not assigned
# 154      M1R       Scarborough
# 155      M4H         East York
# 156      M4M      East Toronto
# 157      M1P       Scarborough
# 158      M6B        North York
# 159      M8Y         Etobicoke
# 160      M1A      Not assigned
# 161      M5E  Downtown Toronto
# 162      M4T   Central Toronto
# 163      M7S      Not assigned
# 164      M8T      Not assigned
# 165      M6H      West Toronto
# 166      M3P      Not assigned
# 167      M8L      Not assigned
# 168      M6K      West Toronto
# 169      M1C       Scarborough
# 170      M2M        North York
# 171      M3H        North York
# 172      M3W      Not assigned
# 173      M3K        North York
# 174      M5R   Central Toronto
# 175      M6M              York
# 176      M5H  Downtown Toronto
# 177      M4W  Downtown Toronto
# 178      M6W      Not assigned
# 179      M2R        North York
#
#                                          Neighbourhood
# 0                      Northwood Park, York University
# 1                                      Don Mills North
# 2                                         Not assigned
# 3                                         Not assigned
# 4                                         Not assigned
# 5                                         Not assigned
# 6                                         East Toronto
# 7                                         Not assigned
# 8                                         Not assigned
# 9                       Commerce Court, Victoria Hotel
# 10                                        Not assigned
# 11   Business Reply Mail Processing Centre 969 Eastern
# 12                                        Not assigned
# 13                                        Not assigned
# 14   Kingsview Village, Martin Grove Gardens, Richv...
# 15                                        Not assigned
# 16                                        Not assigned
# 17       The Kingsway, Montgomery Road, Old Mill North
# 18                                        Not assigned
# 19             Clarks Corners, Sullivan, Tam O'Shanter
# 20                                        Not assigned
# 21   Kingsway Park South West, Mimico NW, The Queen...
# 22                                        Not assigned
# 23                                             Leaside
# 24     Cliffcrest, Cliffside, Scarborough Village West
# 25                                        Not assigned
# 26                                        Not assigned
# 27                                         The Beaches
# 28                   Bedford Park, Lawrence Manor East
# 29                                        Not assigned
# ..                                                 ...
# 150                                       Not assigned
# 151                                       Not assigned
# 152                                       Not assigned
# 153                                       Not assigned
# 154                                  Maryvale, Wexford
# 155                                   Thorncliffe Park
# 156                                    Studio District
# 157  Dorset Park, Scarborough Town Centre, Wexford ...
# 158                                          Glencairn
# 159  Humber Bay, King's Mill Park, Kingsway Park So...
# 160                                       Not assigned
# 161                                        Berczy Park
# 162                        Moore Park, Summerhill East
# 163                                       Not assigned
# 164                                       Not assigned
# 165                       Dovercourt Village, Dufferin
# 166                                       Not assigned
# 167                                       Not assigned
# 168       Brockton, Exhibition Place, Parkdale Village
# 169             Highland Creek, Rouge Hill, Port Union
# 170                            Newtonbrook, Willowdale
# 171    Bathurst Manor, Downsview North, Wilson Heights
# 172                                       Not assigned
# 173                        CFB Toronto, Downsview East
# 174                The Annex, North Midtown, Yorkville
# 175     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 176                           Adelaide, King, Richmond
# 177                                           Rosedale
# 178                                       Not assigned
# 179                                    Willowdale West
#
# [180 rows x 3 columns]

# %%
df=df[df['Borough']!='Not assigned']
df[df['Neighbourhood']=='Not assigned']=df['Borough']
df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3385: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc._setitem_with_indexer(indexer, value)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_array(key, value)
#          Postcode           Borough  \
# 0             M3J        North York
# 1             M3B        North York
# 6             M4J         East York
# 9             M5L  Downtown Toronto
# 11            M7Y      East Toronto
# 14            M9R         Etobicoke
# 16   Queen's Park      Queen's Park
# 17            M8X         Etobicoke
# 19            M1T       Scarborough
# 21            M8Z         Etobicoke
# 23            M4G         East York
# 24            M1M       Scarborough
# 27            M4E      East Toronto
# 28            M5M        North York
# 31            M6S      West Toronto
# 32            M9P         Etobicoke
# 34            M1G       Scarborough
# 36            M4R   Central Toronto
# 37            M4L      East Toronto
# 38            M6L        North York
# 39            M1B       Scarborough
# 41            M4N   Central Toronto
# 42            M2J        North York
# 44            M1X       Scarborough
# 45            M5W  Downtown Toronto
# 46            M9W         Etobicoke
# 47            M9V         Etobicoke
# 48            M1W       Scarborough
# 49            M1E       Scarborough
# 52            M3M        North York
# ..            ...               ...
# 134           M3A        North York
# 136           M5K  Downtown Toronto
# 137           M6G  Downtown Toronto
# 139           M9N              York
# 140           M5G  Downtown Toronto
# 142           M3C        North York
# 143           M4Y  Downtown Toronto
# 144           M5B  Downtown Toronto
# 146           M3N        North York
# 147           M2P        North York
# 148           M6J      West Toronto
# 154           M1R       Scarborough
# 155           M4H         East York
# 156           M4M      East Toronto
# 157           M1P       Scarborough
# 158           M6B        North York
# 159           M8Y         Etobicoke
# 161           M5E  Downtown Toronto
# 162           M4T   Central Toronto
# 165           M6H      West Toronto
# 168           M6K      West Toronto
# 169           M1C       Scarborough
# 170           M2M        North York
# 171           M3H        North York
# 173           M3K        North York
# 174           M5R   Central Toronto
# 175           M6M              York
# 176           M5H  Downtown Toronto
# 177           M4W  Downtown Toronto
# 179           M2R        North York
#
#                                          Neighbourhood
# 0                      Northwood Park, York University
# 1                                      Don Mills North
# 6                                         East Toronto
# 9                       Commerce Court, Victoria Hotel
# 11   Business Reply Mail Processing Centre 969 Eastern
# 14   Kingsview Village, Martin Grove Gardens, Richv...
# 16                                        Queen's Park
# 17       The Kingsway, Montgomery Road, Old Mill North
# 19             Clarks Corners, Sullivan, Tam O'Shanter
# 21   Kingsway Park South West, Mimico NW, The Queen...
# 23                                             Leaside
# 24     Cliffcrest, Cliffside, Scarborough Village West
# 27                                         The Beaches
# 28                   Bedford Park, Lawrence Manor East
# 31                                  Runnymede, Swansea
# 32                                           Westmount
# 34                                              Woburn
# 36                                  North Toronto West
# 37                      The Beaches West, India Bazaar
# 38                  Downsview, North Park, Upwood Park
# 39                                      Rouge, Malvern
# 41                                       Lawrence Park
# 42                        Fairview, Henry Farm, Oriole
# 44                                         Upper Rouge
# 45                     Stn A PO Boxes 25 The Esplanade
# 46                                           Northwest
# 47   Albion Gardens, Beaumond Heights, Humbergate, ...
# 48                                     L'Amoreaux West
# 49                   Guildwood, Morningside, West Hill
# 52                                   Downsview Central
# ..                                                 ...
# 134                                          Parkwoods
# 136           Design Exchange, Toronto Dominion Centre
# 137                                           Christie
# 139                                             Weston
# 140                                 Central Bay Street
# 142                   Flemingdon Park, Don Mills South
# 143                               Church and Wellesley
# 144                           Ryerson, Garden District
# 146                                Downsview Northwest
# 147                                    York Mills West
# 148                           Little Portugal, Trinity
# 154                                  Maryvale, Wexford
# 155                                   Thorncliffe Park
# 156                                    Studio District
# 157  Dorset Park, Scarborough Town Centre, Wexford ...
# 158                                          Glencairn
# 159  Humber Bay, King's Mill Park, Kingsway Park So...
# 161                                        Berczy Park
# 162                        Moore Park, Summerhill East
# 165                       Dovercourt Village, Dufferin
# 168       Brockton, Exhibition Place, Parkdale Village
# 169             Highland Creek, Rouge Hill, Port Union
# 170                            Newtonbrook, Willowdale
# 171    Bathurst Manor, Downsview North, Wilson Heights
# 173                        CFB Toronto, Downsview East
# 174                The Annex, North Midtown, Yorkville
# 175     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 176                           Adelaide, King, Richmond
# 177                                           Rosedale
# 179                                    Willowdale West
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)

# %%
import sys
# !{sys.executable} -m pip install geocoder

print('Packages installed')
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 15.4MB/s ta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Packages installed

# %%
coord = pd.read_csv("https://cocl.us/Geospatial_data")
coord.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %%
coord.columns
# Out:
# Index(['Postal Code', 'Latitude', 'Longitude'], dtype='object')

# %%
coord.rename(columns = {'Postal Code':'Postcode'},inplace=True)
coord.columns
# Out:
# Index(['Postcode', 'Latitude', 'Longitude'], dtype='object')

# %%
total = df.merge(coord,on='Postcode',how='left')
total.head(10)
# Out:
#        Postcode           Borough  \
# 0           M3J        North York
# 1           M3B        North York
# 2           M4J         East York
# 3           M5L  Downtown Toronto
# 4           M7Y      East Toronto
# 5           M9R         Etobicoke
# 6  Queen's Park      Queen's Park
# 7           M8X         Etobicoke
# 8           M1T       Scarborough
# 9           M8Z         Etobicoke
#
#                                        Neighbourhood   Latitude  Longitude
# 0                    Northwood Park, York University  43.767980 -79.487262
# 1                                    Don Mills North  43.745906 -79.352188
# 2                                       East Toronto  43.685347 -79.338106
# 3                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 4  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 5  Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 6                                       Queen's Park        NaN        NaN
# 7      The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 8            Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 9  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
